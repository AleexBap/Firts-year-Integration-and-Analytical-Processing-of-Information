# %%
import os
from astroquery.mast import Observations
from astropy.coordinates import SkyCoord
import pandas as pd

# %%
# Proxima Centauri's ICRS
coord = SkyCoord('14h29m42.94613s', '-62d40m46.16468s', frame='icrs')

tess_csv = 'tessqueries.csv'

if os.path.exists(tess_csv):
    tess_pd = pd.read_csv(tess_csv)
else:
    # Query TESS near Proxima Centauri
    obs_table = Observations.query_criteria(
        obs_collection='tess',  # TESS
        dataproduct_type=['image', 'spectrum', 'catalog'],  # Data type you want
        s_ra=coord.ra.deg,  # Right Ascension of the region
        s_dec=coord.dec.deg,  # Declination of the region
        radius=0.1  # Search radius in degrees
)
    tess_pd = obs_table.to_pandas()
    tess_pd.to_csv('tessqueries.csv', index=False)

# %%
pd.set_option('display.max_columns', None)

# %%
tess_pd
# Out:
#      intentType obs_collection provenance_name instrument_name project  \
# 0       science           TESS            SPOC      Photometer    TESS
# 1       science           TESS            SPOC      Photometer    TESS
# 2       science           TESS            SPOC      Photometer    TESS
# 3       science           TESS            SPOC      Photometer    TESS
# 4       science           TESS            SPOC      Photometer    TESS
# ...         ...            ...             ...             ...     ...
# 1403    science           TESS            SPOC      Photometer    TESS
# 1404    science           TESS            SPOC      Photometer    TESS
# 1405    science           TESS            SPOC      Photometer    TESS
# 1406    science           TESS            SPOC      Photometer    TESS
# 1407    science           TESS            SPOC      Photometer    TESS
#
#      filters wavelength_region target_name  target_classification  \
# 0       TESS           Optical    TESS FFI                    NaN
# 1       TESS           Optical    TESS FFI                    NaN
# 2       TESS           Optical    TESS FFI                    NaN
# 3       TESS           Optical    TESS FFI                    NaN
# 4       TESS           Optical    TESS FFI                    NaN
# ...      ...               ...         ...                    ...
# 1403    TESS           Optical    TESS FFI                    NaN
# 1404    TESS           Optical    TESS FFI                    NaN
# 1405    TESS           Optical    TESS FFI                    NaN
# 1406    TESS           Optical    TESS FFI                    NaN
# 1407    TESS           Optical    TESS FFI                    NaN
#
#               obs_id        s_ra      s_dec dataproduct_type     proposal_pi  \
# 0     tess-s0086-1-1   75.257379  48.394182            image  Ricker, George
# 1     tess-s0086-1-2   57.523191  46.001910            image  Ricker, George
# 2     tess-s0086-1-3   61.742441  34.422100            image  Ricker, George
# 3     tess-s0086-1-4   76.599717  36.405754            image  Ricker, George
# 4     tess-s0086-2-1   71.018345  72.117377            image  Ricker, George
# ...              ...         ...        ...              ...             ...
# 1403  tess-s0088-3-4  118.085778 -54.784110            image  Ricker, George
# 1404  tess-s0088-4-1  110.714292 -66.099514            image  Ricker, George
# 1405  tess-s0088-4-2   87.465791 -59.730241            image  Ricker, George
# 1406  tess-s0088-4-3   66.291166 -67.405962            image  Ricker, George
# 1407  tess-s0088-4-4   92.804009 -76.843686            image  Ricker, George
#
#       calib_level         t_min         t_max   t_exptime  em_min  em_max  \
# 0               3  60635.759117  60662.331107  158.399926   600.0  1000.0
# 1               3  60635.759398  60662.330808  158.399926   600.0  1000.0
# 2               3  60635.759793  60662.331209  158.399926   600.0  1000.0
# 3               3  60635.759513  60662.331509  158.399926   600.0  1000.0
# 4               3  60635.757750  60662.329734  158.399926   600.0  1000.0
# ...           ...           ...           ...         ...     ...     ...
# 1403            3  60689.646842  60717.424963  158.399925   600.0  1000.0
# 1404            3  60689.645772  60717.423884  158.399925   600.0  1000.0
# 1405            3  60689.646077  60717.423585  158.399925   600.0  1000.0
# 1406            3  60689.644881  60717.422378  158.399925   600.0  1000.0
# 1407            3  60689.644577  60717.422679  158.399925   600.0  1000.0
#
#       obs_title  t_obs_release  proposal_id  proposal_type  sequence_number  \
# 0           NaN        60697.0          NaN            NaN               86
# 1           NaN        60697.0          NaN            NaN               86
# 2           NaN        60697.0          NaN            NaN               86
# 3           NaN        60697.0          NaN            NaN               86
# 4           NaN        60697.0          NaN            NaN               86
# ...         ...            ...          ...            ...              ...
# 1403        NaN        60734.0          NaN            NaN               88
# 1404        NaN        60734.0          NaN            NaN               88
# 1405        NaN        60734.0          NaN            NaN               88
# 1406        NaN        60734.0          NaN            NaN               88
# 1407        NaN        60734.0          NaN            NaN               88
#
#                                                s_region  jpegURL  dataURL  \
# 0     POLYGON 84.397259 54.220049 84.340478 42.73188...      NaN      NaN
# 1     POLYGON 64.081165 53.379423 67.62671 41.711452...      NaN      NaN
# 2     POLYGON 56.900467 27.410355 52.298245 38.23203...      NaN      NaN
# 3     POLYGON 70.29962 29.735295 67.909289 41.484483...      NaN      NaN
# 4     POLYGON 95.427814 77.267546 87.798089 66.01251...      NaN      NaN
# ...                                                 ...      ...      ...
# 1403  POLYGON 103.995769 -58.278586 111.769394 -47.3...      NaN      NaN
# 1404  POLYGON 126.593612 -61.814511 124.108074 -73.2...      NaN      NaN
# 1405  POLYGON 103.675924 -58.111101 89.215174 -68.14...      NaN      NaN
# 1406  POLYGON 48.343253 -63.919623 70.359333 -59.102...      NaN      NaN
# 1407  POLYGON 57.070484 -75.528303 89.037206 -68.474...      NaN      NaN
#
#      dataRights  mtFlag  srcDen      obsid      objID
# 0        PUBLIC   False     NaN  236870228  700694124
# 1        PUBLIC   False     NaN  236870229  700703621
# 2        PUBLIC   False     NaN  236870242  700713800
# 3        PUBLIC   False     NaN  236870243  700721420
# 4        PUBLIC   False     NaN  236870245  700730556
# ...         ...     ...     ...        ...        ...
# 1403     PUBLIC   False     NaN  247910493  732056593
# 1404     PUBLIC   False     NaN  247913721  732067225
# 1405     PUBLIC   False     NaN  247916479  732076216
# 1406     PUBLIC   False     NaN  247919459  732085054
# 1407     PUBLIC   False     NaN  247922567  732095520
#
# [1408 rows x 33 columns]
